# %%
import gymnasium as gym

env = gym.make("room_env:RoomEnv-v0", num_agents=2)
(observation, question), info = env.reset()
rewards = 0

while True:
    (observation, question), reward, done, truncated, info = env.step(
        "This is my answer!"
    )
    rewards += reward
    print((observation, question), reward, done, truncated, info)
    if done:
        break

print(rewards)
# Out:
# /home/tk/.virtualenvs/human-memory/lib/python3.9/site-packages/gymnasium/envs/registration.py:578: UserWarning: WARN: The environment RoomEnv-v0 is out of date. You should consider upgrading to version `v2`.
#   logger.warn(
# /home/tk/.virtualenvs/human-memory/lib/python3.9/site-packages/gymnasium/envs/registration.py:435: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes']
#   logger.warn(
# 2023-08-15 22:00:46.209 WARNING room0 - __init__: The obserations will be limited by {'heads': None, 'tails': None, 'names': None, 'allow_spaces': False}
# 2023-08-15 22:00:46.210 WARNING room0 - load_semantic_knowledge: Tails that are heads will be removed.
# 2023-08-15 22:00:46.210 INFO room0 - load_semantic_knowledge: empty entities are removed
# 2023-08-15 22:00:46.211 INFO room0 - load_semantic_knowledge: semantic knowledge successfully loaded from ./data/semantic-knowledge-small.json!
# 2023-08-15 22:00:46.211 INFO room0 - read_names: Reading ./data/top-human-names-small complete! There are 10 names in total
# /home/tk/.virtualenvs/human-memory/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:190: UserWarning: WARN: Future gymnasium versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /home/tk/.virtualenvs/human-memory/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:203: UserWarning: WARN: Future gymnasium versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /home/tk/.virtualenvs/human-memory/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:149: UserWarning: WARN: The obs returned by the `reset()` method should be an int or np.int64, actual type: <class 'tuple'>
#   logger.warn(f"{pre} should be an int or np.int64, actual type: {type(obs)}")
# /home/tk/.virtualenvs/human-memory/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:181: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# 2023-08-15 22:00:46.212 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# /home/tk/.virtualenvs/human-memory/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:149: UserWarning: WARN: The obs returned by the `step()` method should be an int or np.int64, actual type: <class 'tuple'>
#   logger.warn(f"{pre} should be an int or np.int64, actual type: {type(obs)}")
# /home/tk/.virtualenvs/human-memory/lib/python3.9/site-packages/gymnasium/utils/passive_env_checker.py:181: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# 2023-08-15 22:00:46.213 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.213 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.214 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.214 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.215 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.215 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.216 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.216 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.216 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.217 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.217 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.217 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.218 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.218 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.218 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.219 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.220 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.220 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.220 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.221 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.221 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.222 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.222 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.223 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.223 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.223 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.224 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.224 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.224 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.225 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.225 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.226 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.226 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.227 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.227 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.227 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.228 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.228 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.228 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.229 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.229 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.229 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.230 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.230 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.231 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.231 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.231 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.232 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.232 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.232 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.233 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.233 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.234 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.234 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.234 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.235 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.235 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.235 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.236 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.236 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.236 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.237 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.237 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.238 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.238 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.238 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.239 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.239 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.240 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.240 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.244 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.245 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.245 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.246 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.246 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.246 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.247 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.247 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.248 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.248 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.248 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.249 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.249 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.250 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.250 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.250 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.251 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.251 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.251 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.252 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.252 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.252 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.253 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.253 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.254 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.254 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.255 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.255 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.256 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.256 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.257 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.257 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.258 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.258 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.258 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.259 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.259 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.260 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.260 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.261 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.261 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.261 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.262 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.262 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.263 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.263 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.263 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.264 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.264 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.265 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.265 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.265 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.266 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.266 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.267 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.267 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.268 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.268 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.268 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.269 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.273 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.274 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.274 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.275 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.275 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.275 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.276 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.276 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.276 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.277 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.277 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.278 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.278 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.278 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.279 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.279 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.280 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.280 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.281 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.281 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.282 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.282 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.282 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.283 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.283 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.283 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.284 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.284 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.285 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.285 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.285 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.286 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.286 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.287 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.287 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.287 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.288 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.288 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.289 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.289 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.289 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.290 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.290 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.291 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.291 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.291 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.292 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.292 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.293 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.293 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.293 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.294 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.294 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.295 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.295 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.295 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.296 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.296 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.297 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.297 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.297 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.298 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.298 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.298 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.299 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.299 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.299 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.300 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.302 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.303 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.303 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.304 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.304 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.305 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.305 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.305 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.306 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.306 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.307 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.307 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.307 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.308 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.308 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.308 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.309 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.309 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.309 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.310 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.310 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.310 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.311 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.311 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.312 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.312 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.313 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.313 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.313 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.314 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.314 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.314 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.315 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.315 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.316 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.316 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.316 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.317 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.317 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.318 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.318 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.318 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.319 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.319 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.320 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.320 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.321 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.321 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.322 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.322 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.322 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.323 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.323 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.324 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.324 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.324 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.325 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.325 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.325 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.326 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.326 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.327 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.327 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.327 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.328 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.328 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.329 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.329 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.330 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.330 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.330 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.331 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.331 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.332 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.332 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.332 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.333 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.333 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.334 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.334 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.334 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.335 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.335 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.335 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.336 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.336 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.337 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.337 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.337 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.338 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.338 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.339 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.339 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.339 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.340 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.340 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.341 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.341 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.341 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.342 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.342 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.342 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.343 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.343 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.344 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.345 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.345 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.346 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.347 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.348 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.348 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.349 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.349 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.350 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.350 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.351 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.352 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.352 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.360 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.372 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.373 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.374 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.374 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.375 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.376 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.377 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.378 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.378 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.379 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.379 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.380 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.380 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.381 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.382 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.382 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.383 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.384 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.384 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.385 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.385 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.386 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.387 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.387 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.388 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.388 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.389 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.389 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.390 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.391 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.391 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.394 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.394 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.395 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.395 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.396 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.396 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.397 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.397 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.398 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.398 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.399 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.399 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.399 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (garage)!
# 2023-08-15 22:00:46.400 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# 2023-08-15 22:00:46.400 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.401 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.401 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.402 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.402 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.402 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.403 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.403 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.404 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.404 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.405 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.405 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.406 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.406 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.407 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.407 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.408 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.408 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.409 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.409 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.410 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.410 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.411 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.411 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.412 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.412 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.413 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.413 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (office)!
# ({0: ["Robert's couch", 'atlocation', "Robert's tree", 1], 1: ["Charles's chair", 'atlocation', "Charles's office", 1]}, ["Thomas's cat", 'atlocation']) 0 False False {}
# ({0: ["Charles's chair", 'atlocation', "Charles's office", 2], 1: ["James's cat", 'atlocation', "James's lap", 2]}, ["Thomas's cat", 'atlocation']) 0 False False {}
# ({0: ["Michael's car", 'atlocation', "Michael's city", 3], 1: ["Joseph's bicycle", 'atlocation', "Joseph's garage", 3]}, ["William's cup", 'atlocation']) 0 False False {}
# ...
# ({0: ["David's bird", 'atlocation', "David's office", 930], 1: ["William's person", 'atlocation', "William's park", 930]}, ["Charles's bicycle", 'atlocation']) 0 False False {}
# ({0: ["Charles's laptop", 'atlocation', "Charles's building", 931], 1: ["Richard's person", 'atlocation', "Richard's lap", 931]}, ["William's person", 'atlocation']) 0 False False {}
# ({0: ["James's couch", 'atlocation', "James's garage", 932], 1: ["Joseph's bird", 'atlocation', "Joseph's building", 932]}, ["David's bird", 'atlocation']) 0 False False {}
# ({0: ["John's bird", 'atlocation', "John's office", 933], 1: ["David's chair", 'atlocation', "David's office", 933]}, ["Joseph's bird", 'atlocation']) 0 False False {}
# ({0: ["Robert's chair", 'atlocation', "Robert's office", 934], 1: ["Michael's cup", 'atlocation', "Michael's desk", 934]}, ["William's person", 'atlocation']) 0 False False {}
# ({0: ["Charles's laptop", 'atlocation', "Charles's building", 935], 1: ["Thomas's chair", 'atlocation', "Thomas's garage", 935]}, ["Robert's chair", 'atlocation']) 0 False False {}
# ({0: ["Joseph's bird", 'atlocation', "Joseph's tree", 936], 1: ["Richard's person", 'atlocation', "Richard's lap", 936]}, ["James's couch", 'atlocation']) 0 False False {}
# ({0: ["Thomas's chair", 'atlocation', "Thomas's house", 937], 1: ["James's couch", 'atlocation', "James's garage", 937]}, ["Thomas's chair", 'atlocation']) 0 False False {}
# ({0: ["William's person", 'atlocation', "William's park", 938], 1: ["John's bird", 'atlocation', "John's house", 938]}, ["William's person", 'atlocation']) 0 False False {}
# ({0: ["Michael's person", 'atlocation', "Michael's building", 939], 1: ["Robert's chair", 'atlocation', "Robert's lap", 939]}, ["Robert's chair", 'atlocation']) 0 False False {}
# ({0: ["Charles's laptop", 'atlocation', "Charles's building", 940], 1: ["William's person", 'atlocation', "William's office", 940]}, ["Joseph's dog", 'atlocation']) 0 False False {}
# ({0: ["David's chair", 'atlocation', "David's lap", 941], 1: ["Robert's couch", 'atlocation', "Robert's house", 941]}, ["Charles's laptop", 'atlocation']) 0 False False {}
# ({0: ["James's bird", 'atlocation', "James's lap", 942], 1: ["Richard's bicycle", 'atlocation', "Richard's tree", 942]}, ["Charles's laptop", 'atlocation']) 0 False False {}
# ({0: ["John's couch", 'atlocation', "John's table", 943], 1: ["Charles's chair", 'atlocation', "Charles's office", 943]}, ["David's chair", 'atlocation']) 0 False False {}
# ({0: ["Joseph's dog", 'atlocation', "Joseph's tree", 944], 1: ["Thomas's chair", 'atlocation', "Thomas's table", 944]}, ["Joseph's dog", 'atlocation']) 0 False False {}
# ({0: ["David's chair", 'atlocation', "David's lap", 945], 1: ["Michael's couch", 'atlocation', "Michael's house", 945]}, ["Joseph's dog", 'atlocation']) 0 False False {}
# ({0: ["Richard's bird", 'atlocation', "Richard's tree", 946], 1: ["Robert's couch", 'atlocation', "Robert's house", 946]}, ["Thomas's chair", 'atlocation']) 0 False False {}
# ({0: ["David's chair", 'atlocation', "David's office", 947], 1: ["James's bird", 'atlocation', "James's lap", 947]}, ["William's person", 'atlocation']) 0 False False {}
# ({0: ["Charles's chair", 'atlocation', "Charles's office", 948], 1: ["Michael's couch", 'atlocation', "Michael's house", 948]}, ["Robert's couch", 'atlocation']) 0 False False {}
# ({0: ["William's person", 'atlocation', "William's office", 949], 1: ["John's cat", 'atlocation', "John's desk", 949]}, ["Charles's chair", 'atlocation']) 0 False False {}
# ({0: ["Thomas's chair", 'atlocation', "Thomas's office", 950], 1: ["Charles's chair", 'atlocation', "Charles's office", 950]}, ["Richard's dog", 'atlocation']) 0 False False {}
# ({0: ["Robert's couch", 'atlocation', "Robert's house", 951], 1: ["Joseph's car", 'atlocation', "Joseph's office", 951]}, ["John's person", 'atlocation']) 0 False False {}
# ({0: ["James's chair", 'atlocation', "James's office", 952], 1: ["Richard's dog", 'atlocation', "Richard's desk", 952]}, ["John's person", 'atlocation']) 0 False False {}
# ({0: ["David's laptop", 'atlocation', "David's desk", 953], 1: ["Thomas's bird", 'atlocation', "Thomas's tree", 953]}, ["Michael's couch", 'atlocation']) 0 False False {}
# ({0: ["Thomas's bird", 'atlocation', "Thomas's tree", 954], 1: ["William's chair", 'atlocation', "William's tree", 954]}, ["John's person", 'atlocation']) 0 False False {}
# ({0: ["William's chair", 'atlocation', "William's tree", 955], 1: ["Michael's couch", 'atlocation', "Michael's house", 955]}, ["Joseph's car", 'atlocation']) 0 False False {}
# ({0: ["Richard's bird", 'atlocation', "Richard's house", 956], 1: ["Robert's couch", 'atlocation', "Robert's house", 956]}, ["Thomas's bird", 'atlocation']) 0 False False {}
# ({0: ["Michael's couch", 'atlocation', "Michael's house", 957], 1: ["James's chair", 'atlocation', "James's office", 957]}, ["Thomas's bird", 'atlocation']) 0 False False {}
# ({0: ["Charles's chair", 'atlocation', "Charles's desk", 958], 1: ["Richard's bird", 'atlocation', "Richard's tree", 958]}, ["Michael's couch", 'atlocation']) 0 False False {}
# ({0: ["Joseph's car", 'atlocation', "Joseph's office", 959], 1: ["Thomas's bird", 'atlocation', "Thomas's tree", 959]}, ["Charles's chair", 'atlocation']) 0 False False {}
# ({0: ["John's car", 'atlocation', "John's house", 960], 1: ["Charles's chair", 'atlocation', "Charles's desk", 960]}, ["John's car", 'atlocation']) 0 False False {}
# ({0: ["Robert's dog", 'atlocation', "Robert's park", 961], 1: ["Richard's bird", 'atlocation', "Richard's tree", 961]}, ["Richard's bird", 'atlocation']) 0 False False {}
# ({0: ["Michael's car", 'atlocation', "Michael's city", 962], 1: ["David's bicycle", 'atlocation', "David's garage", 962]}, ["Robert's dog", 'atlocation']) 0 False False {}
# ({0: ["William's bird", 'atlocation', "William's tree", 963], 1: ["John's car", 'atlocation', "John's house", 963]}, ["David's bicycle", 'atlocation']) 0 False False {}
# ({0: ["Thomas's dog", 'atlocation', "Thomas's park", 964], 1: ["Joseph's chair", 'atlocation', "Joseph's office", 964]}, ["David's bicycle", 'atlocation']) 0 False False {}
# ({0: ["Richard's bird", 'atlocation', "Richard's tree", 965], 1: ["James's cup", 'atlocation', "James's table", 965]}, ["James's cup", 'atlocation']) 0 False False {}
# ({0: ["John's bicycle", 'atlocation', "John's garage", 966], 1: ["Charles's person", 'atlocation', "Charles's garage", 966]}, ["James's cup", 'atlocation']) 0 False False {}
# 2023-08-15 22:00:46.823 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.826 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.827 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.828 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.830 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.831 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.832 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.833 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.834 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.835 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.837 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.838 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.839 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.839 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.840 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.841 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (building)!
# 2023-08-15 22:00:46.842 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.842 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.843 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.845 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.845 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.847 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.847 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (park)!
# 2023-08-15 22:00:46.850 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.851 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (table)!
# 2023-08-15 22:00:46.852 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (desk)!
# 2023-08-15 22:00:46.853 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (tree)!
# 2023-08-15 22:00:46.854 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.855 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.856 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (city)!
# 2023-08-15 22:00:46.857 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (house)!
# 2023-08-15 22:00:46.859 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# 2023-08-15 22:00:46.860 INFO room0 - step: The prediction (This is my answer!) does NOT match the answer (lap)!
# ({0: ["James's cup", 'atlocation', "James's table", 967], 1: ["Michael's car", 'atlocation', "Michael's desk", 967]}, ["Charles's person", 'atlocation']) 0 False False {}
# ({0: ["Robert's dog", 'atlocation', "Robert's park", 968], 1: ["Charles's person", 'atlocation', "Charles's building", 968]}, ["James's cup", 'atlocation']) 0 False False {}
# ({0: ["Richard's bicycle", 'atlocation', "Richard's tree", 969], 1: ["Thomas's bird", 'atlocation', "Thomas's lap", 969]}, ["Joseph's chair", 'atlocation']) 0 False False {}
# ({0: ["David's cup", 'atlocation', "David's table", 970], 1: ["Robert's laptop", 'atlocation', "Robert's desk", 970]}, ["William's bird", 'atlocation']) 0 False False {}
# ({0: ["William's bird", 'atlocation', "William's tree", 971], 1: ["Joseph's chair", 'atlocation', "Joseph's desk", 971]}, ["Joseph's chair", 'atlocation']) 0 False False {}
# ({0: ["James's person", 'atlocation', "James's house", 972], 1: ["John's dog", 'atlocation', "John's house", 972]}, ["Richard's dog", 'atlocation']) 0 False False {}
# ({0: ["Michael's car", 'atlocation', "Michael's city", 973], 1: ["David's cup", 'atlocation', "David's table", 973]}, ["Robert's laptop", 'atlocation']) 0 False False {}
# ({0: ["Charles's person", 'atlocation', "Charles's building", 974], 1: ["Richard's dog", 'atlocation', "Richard's tree", 974]}, ["Michael's car", 'atlocation']) 0 False False {}
# ({0: ["Joseph's chair", 'atlocation', "Joseph's desk", 975], 1: ["Thomas's dog", 'atlocation', "Thomas's lap", 975]}, ["John's dog", 'atlocation']) 0 False False {}
# ({0: ["John's dog", 'atlocation', "John's park", 976], 1: ["William's dog", 'atlocation', "William's park", 976]}, ["Robert's laptop", 'atlocation']) 0 False False {}
# ({0: ["Robert's laptop", 'atlocation', "Robert's park", 977], 1: ["David's cup", 'atlocation', "David's table", 977]}, ["Joseph's chair", 'atlocation']) 0 False False {}
# ({0: ["Thomas's dog", 'atlocation', "Thomas's park", 978], 1: ["Michael's car", 'atlocation', "Michael's house", 978]}, ["Richard's cat", 'atlocation']) 0 False False {}
# ({0: ["Richard's cat", 'atlocation', "Richard's table", 979], 1: ["Charles's bicycle", 'atlocation', "Charles's tree", 979]}, ["Charles's bicycle", 'atlocation']) 0 False False {}
# ({0: ["James's person", 'atlocation', "James's building", 980], 1: ["Thomas's dog", 'atlocation', "Thomas's park", 980]}, ["John's cup", 'atlocation']) 0 False False {}
# ({0: ["Michael's dog", 'atlocation', "Michael's park", 981], 1: ["Joseph's chair", 'atlocation', "Joseph's desk", 981]}, ["John's cup", 'atlocation']) 0 False False {}
# ({0: ["David's cup", 'atlocation', "David's table", 982], 1: ["Richard's cat", 'atlocation', "Richard's table", 982]}, ["William's dog", 'atlocation']) 0 False False {}
# ({0: ["Robert's laptop", 'atlocation', "Robert's building", 983], 1: ["James's person", 'atlocation', "James's building", 983]}, ["William's dog", 'atlocation']) 0 False False {}
# ({0: ["Charles's bicycle", 'atlocation', "Charles's garage", 984], 1: ["William's dog", 'atlocation', "William's table", 984]}, ["David's cup", 'atlocation']) 0 False False {}
# ({0: ["Joseph's chair", 'atlocation', "Joseph's desk", 985], 1: ["John's cup", 'atlocation', "John's park", 985]}, ["Michael's cup", 'atlocation']) 0 False False {}
# ({0: ["Michael's cup", 'atlocation', "Michael's garage", 986], 1: ["Thomas's dog", 'atlocation', "Thomas's city", 986]}, ["Joseph's chair", 'atlocation']) 0 False False {}
# ({0: ["John's cup", 'atlocation', "John's park", 987], 1: ["Richard's cat", 'atlocation', "Richard's lap", 987]}, ["Charles's bicycle", 'atlocation']) 0 False False {}
# ({0: ["William's couch", 'atlocation', "William's tree", 988], 1: ["Robert's dog", 'atlocation', "Robert's park", 988]}, ["John's cup", 'atlocation']) 0 False False {}
# ({0: ["David's couch", 'atlocation', "David's house", 989], 1: ["Charles's bicycle", 'atlocation', "Charles's tree", 989]}, ["Robert's dog", 'atlocation']) 0 False False {}
# ({0: ["James's laptop", 'atlocation', "James's desk", 990], 1: ["William's couch", 'atlocation', "William's tree", 990]}, ["Robert's cup", 'atlocation']) 0 False False {}
# ({0: ["John's cup", 'atlocation', "John's table", 991], 1: ["Joseph's laptop", 'atlocation', "Joseph's desk", 991]}, ["John's cup", 'atlocation']) 0 False False {}
# ({0: ["Richard's cat", 'atlocation', "Richard's garage", 992], 1: ["Michael's cup", 'atlocation', "Michael's lap", 992]}, ["James's laptop", 'atlocation']) 0 False False {}
# ({0: ["Joseph's laptop", 'atlocation', "Joseph's desk", 993], 1: ["James's laptop", 'atlocation', "James's desk", 993]}, ["William's couch", 'atlocation']) 0 False False {}
# ({0: ["Charles's cat", 'atlocation', "Charles's lap", 994], 1: ["David's couch", 'atlocation', "David's house", 994]}, ["David's couch", 'atlocation']) 0 False False {}
# ({0: ["Robert's cup", 'atlocation', "Robert's lap", 995], 1: ["Thomas's dog", 'atlocation', "Thomas's city", 995]}, ["William's bicycle", 'atlocation']) 0 False False {}
# ({0: ["Michael's cup", 'atlocation', "Michael's table", 996], 1: ["John's cup", 'atlocation', "John's table", 996]}, ["Thomas's dog", 'atlocation']) 0 False False {}
# ({0: ["William's bicycle", 'atlocation', "William's garage", 997], 1: ["Richard's cat", 'atlocation', "Richard's table", 997]}, ["David's couch", 'atlocation']) 0 False False {}
# ({0: ["Thomas's dog", 'atlocation', "Thomas's city", 998], 1: ["David's couch", 'atlocation', "David's desk", 998]}, ["Charles's cat", 'atlocation']) 0 False False {}
# ({0: ["Joseph's cup", 'atlocation', "Joseph's table", 999], 1: ["Charles's cat", 'atlocation', "Charles's lap", 999]}, ["Robert's cup", 'atlocation']) 0 False False {}
# ({0: ["David's couch", 'atlocation', "David's desk", 1000], 1: ["Thomas's chair", 'atlocation', "Thomas's office", 1000]}, ["Thomas's chair", 'atlocation']) 0 True False {}
# 0

# %%
(observation, question), reward, done, truncated, info
# Out:
# (({0: ["David's couch", 'atlocation', "David's desk", 1000],
#    1: ["Thomas's chair", 'atlocation', "Thomas's office", 1000]},
#   ["Thomas's chair", 'atlocation']),
#  0,
#  True,
#  False,
#  {})
